# %%
from pandas import *
from numpy import *
from sklearn import *
from sklearn.linear_model import *
from sklearn.metrics import *
from sklearn.model_selection import *
from sklearn.linear_model import Ridge

# %%
data=read_csv("new_train.csv")
data1=data.iloc[:,1:]
data1
# Out:
#      Open-Stock-1  High-Stock-1  Low-Stock-1  Close-Stock-1  VWAP-Stock-1  \
# 0         1889.70       1890.00      1838.00        1855.10       1855.75
# 1         1848.00       1862.75      1828.00        1853.05       1842.82
# 2         1864.10       1910.00      1864.10        1905.60       1893.91
# 3         1906.00       1909.80      1880.10        1885.70       1889.21
# 4         1867.00       1894.85      1808.35        1876.65       1873.32
# ..            ...           ...          ...            ...           ...
# 294        499.50        499.50       484.60         487.30        489.79
# 295        489.90        489.90       481.10         486.80        485.65
# 296        493.45        495.95       484.50         488.00        489.14
# 297        487.90        487.90       480.00         482.85        483.30
# 298        478.70        489.40       476.00         482.05        481.89
#
#      Volume-Stock-1  Turnover-Stock-1  Open-Stock-2  High-Stock-2  \
# ...

# %%
x=data1.drop(['Close-Stock-1','Close-Stock-2','Close-Stock-3','Close-Stock-4','Close-Stock-5', 'Turnover-Stock-1', 'Turnover-Stock-2', 'Turnover-Stock-3', 'Turnover-Stock-4', 'Turnover-Stock-5', 'Volume-Stock-1', 'Volume-Stock-2', 'Volume-Stock-3', 'Volume-Stock-4', 'Volume-Stock-5'],axis=1)
y=data[['Close-Stock-1','Close-Stock-2','Close-Stock-3','Close-Stock-4','Close-Stock-5']]

# %%
x['Avg-Stock-1'] = (x['High-Stock-1'] + x['Low-Stock-1'])/2
x['Avg-Stock-2'] = (x['High-Stock-2'] + x['Low-Stock-2'])/2
x['Avg-Stock-3'] = (x['High-Stock-3'] + x['Low-Stock-3'])/2
x['Avg-Stock-4'] = (x['High-Stock-4'] + x['Low-Stock-4'])/2
x['Avg-Stock-5'] = (x['High-Stock-5'] + x['Low-Stock-5'])/2

x['Stock-1'] = (x['High-Stock-1'] - x['Low-Stock-1'])
x['Stock-2'] = (x['High-Stock-2'] - x['Low-Stock-2'])
x['Stock-3'] = (x['High-Stock-3'] - x['Low-Stock-3'])
x['Stock-4'] = (x['High-Stock-4'] - x['Low-Stock-4'])
x['Stock-5'] = (x['High-Stock-5'] - x['Low-Stock-5'])

#x['Avg1'] = (x['VWAP-Stock-1'] + x['Avg-Stock-1'])/2
#x['Avg2'] = (x['VWAP-Stock-2'] + x['Avg-Stock-2'])/2
#x['Avg3'] = (x['VWAP-Stock-3'] + x['Avg-Stock-3'])/2
#x['Avg4'] = (x['VWAP-Stock-4'] + x['Avg-Stock-4'])/2
#x['Avg5'] = (x['VWAP-Stock-5'] + x['Avg-Stock-5'])/2
x.head()
# Out:
#    Open-Stock-1  High-Stock-1  Low-Stock-1  VWAP-Stock-1  Open-Stock-2  \
# 0        1889.7       1890.00      1838.00       1855.75        285.40
# 1        1848.0       1862.75      1828.00       1842.82        284.00
# 2        1864.1       1910.00      1864.10       1893.91        283.00
# 3        1906.0       1909.80      1880.10       1889.21        288.85
# 4        1867.0       1894.85      1808.35       1873.32        285.00
#
#    High-Stock-2  Low-Stock-2  VWAP-Stock-2  Open-Stock-3  High-Stock-3  ...  \
# 0        285.95       281.50        283.72       2095.00        2097.8  ...
# 1        284.80       279.25        281.05       2061.45        2098.0  ...
# 2        286.85       282.50        285.34       2131.50        2131.5  ...
# 3        291.80       277.00        289.81       2114.90        2156.0  ...
# 4        289.10       285.00        287.01       2132.35        2209.0  ...
#
#    VWAP-Stock-4  Open-Stock-5  High-Stock-5  Low-Stock-5  VWAP-Stock-5  \
# ...

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2)

# %%
model=LinearRegression()
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
output=DataFrame(model.predict(test_x))
output.head()
# Out:
#              0           1            2            3            4
# 0  2195.109359  160.534297  2767.866829   988.529958  1369.586737
# 1  2270.635704  190.122834  2849.473531  1025.827710  1210.601671
# 2  2101.323706  172.794408  2668.858297  1046.792563  1296.654295
# 3  2488.929510  179.080886  2791.204276  1105.825209  1494.971638
# 4  2293.523499  169.998195  2620.336859  1141.047878  1360.306886

# %%
print("r2 score is",r2_score(test_y,output))
print("mean absolute error is",mean_absolute_error(test_y,output))
# Out:
# r2 score is 0.9955963139566386
# mean absolute error is 6.2022489194398185

# %%
print("r2 score is",r2_score(test_y,output))
print("mean absolute error is",mean_absolute_error(test_y,output))
# Out:
# r2 score is 0.9955963139566386
# mean absolute error is 6.2022489194398185

# %%
test_data=read_csv('new_test.csv')
test=test_data.iloc[:,1:]

# %%
test=test.drop(['Turnover-Stock-1', 'Turnover-Stock-2', 'Turnover-Stock-3', 'Turnover-Stock-4', 'Turnover-Stock-5', 'Volume-Stock-1', 'Volume-Stock-2', 'Volume-Stock-3', 'Volume-Stock-4', 'Volume-Stock-5'], axis=1)

test['Avg-Stock-1'] = (test['High-Stock-1'] + test['Low-Stock-1'])/2
test['Avg-Stock-2'] = (test['High-Stock-2'] + test['Low-Stock-2'])/2
test['Avg-Stock-3'] = (test['High-Stock-3'] + test['Low-Stock-3'])/2
test['Avg-Stock-4'] = (test['High-Stock-4'] + test['Low-Stock-4'])/2
test['Avg-Stock-5'] = (test['High-Stock-5'] + test['Low-Stock-5'])/2

test['Stock-1'] = (test['High-Stock-1'] - test['Low-Stock-1'])
test['Stock-2'] = (test['High-Stock-2'] - test['Low-Stock-2'])
test['Stock-3'] = (test['High-Stock-3'] - test['Low-Stock-3'])
test['Stock-4'] = (test['High-Stock-4'] - test['Low-Stock-4'])
test['Stock-5'] = (test['High-Stock-5'] - test['Low-Stock-5'])


#test['Avg1'] = (test['VWAP-Stock-1'] + test['Avg-Stock-1'])/2
#test['Avg2'] = (test['VWAP-Stock-2'] + test['Avg-Stock-2'])/2
#test['Avg3'] = (test['VWAP-Stock-3'] + test['Avg-Stock-3'])/2
#test['Avg4'] = (test['VWAP-Stock-4'] + test['Avg-Stock-4'])/2
#test['Avg5'] = (test['VWAP-Stock-5'] + test['Avg-Stock-5'])/2

# %%
output=DataFrame(model.predict(test))

# %%
result=DataFrame()
result['Date']=test_data['Date']
result['Close-Stock-1']=output.iloc[:,0]
result['Close-Stock-2']=output.iloc[:,1]
result['Close-Stock-3']=output.iloc[:,2]
result['Close-Stock-4']=output.iloc[:,3]
result['Close-Stock-5']=output.iloc[:,4]
result.head
# Out:
# <bound method NDFrame.head of           Date  Close-Stock-1  Close-Stock-2  Close-Stock-3  Close-Stock-4  \
# 0   2011-08-04     474.506291     202.260359    3083.162061     998.827450
# 1   2011-08-05     465.049216     194.404701    3054.654980     957.028374
# 2   2011-08-08     473.557621     194.959443    3078.477576     961.368727
# 3   2011-08-09     476.061193     199.079825    3115.094784     951.005660
# 4   2011-08-10     473.381093     198.126890    3171.778594     961.749333
# ..         ...            ...            ...            ...            ...
# 92  2011-12-22     447.204815     203.665469    2719.529360     716.981730
# 93  2011-12-23     437.443399     202.801198    2688.840835     716.199586
# 94  2011-12-26     440.184852     204.778731    2673.376536     725.877328
# 95  2011-12-27     433.368977     204.131541    2681.463840     722.070366
# 96  2011-12-28     429.407931     201.499585    2628.846179     693.295228
#
#     Close-Stock-5
# 0     1292.303488
# ...

# %%
result.to_csv("ans68.csv",index=False)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
lasso_params = {'fit__alpha':[0.005, 0.02, 0.03, 0.05, 0.06]}
ridge_params = {'fit__alpha':[550, 580, 600, 620, 650]}

pipe1 = Pipeline([('poly', PolynomialFeatures()),
                 ('fit', linear_model.LinearRegression())])
pipe2 = Pipeline([('poly', PolynomialFeatures()),
                 ('fit', linear_model.Lasso())])
pipe3 = Pipeline([('poly', PolynomialFeatures()),
                 ('fit', linear_model.Ridge())])

models3 = {'OLS': pipe1,
           'Lasso': GridSearchCV(pipe2, 
                                 param_grid=lasso_params).fit(train_x,train_y).best_estimator_ ,
           'Ridge': GridSearchCV(pipe3, 
                                 param_grid=ridge_params).fit(train_x,train_y).best_estimator_,}
# Out:
# /home/kamesh/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7649.506540756831, tolerance: 2775.7877917958112
#   model = cd_fast.enet_coordinate_descent(
# /home/kamesh/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.07408989010649, tolerance: 41.85496127486912
#   model = cd_fast.enet_coordinate_descent(
# /home/kamesh/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9598.803331288764, tolerance: 1067.0447674319373
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
corr_matrix=x.corr()
corr_matrix['Avg-Stock-1'].sort_values(ascending=False)
# Out:
# Avg-Stock-1       1.000000
# VWAP-Stock-1      0.999788
# High-Stock-1      0.999636
# Low-Stock-1       0.999619
# Open-Stock-1      0.998877
# VWAP-Stock-4      0.315362
# Low-Stock-4       0.313762
# Avg-Stock-4       0.313271
# Open-Stock-4      0.312313
# High-Stock-4      0.310969
# Open-Stock-5      0.300983
# High-Stock-5      0.300822
# Avg-Stock-5       0.294601
# VWAP-Stock-5      0.293920
# Low-Stock-5       0.285644
# Volume-Stock-4    0.083652
# Volume-Stock-3    0.046135
# Volume-Stock-2    0.044938
# Volume-Stock-5   -0.048699
# High-Stock-3     -0.095199
# Avg-Stock-3      -0.105783
# Open-Stock-3     -0.106280
# VWAP-Stock-3     -0.106869
# Low-Stock-3      -0.116020
# Open-Stock-2     -0.243428
# High-Stock-2     -0.244038
# Avg-Stock-2      -0.244372
# Low-Stock-2      -0.244522
# VWAP-Stock-2     -0.244853
# Volume-Stock-1   -0.650727
# Name: Avg-Stock-1, dtype: float64

# %%
x.head()
# Out:
#    Open-Stock-1  High-Stock-1  Low-Stock-1  VWAP-Stock-1  Open-Stock-2  \
# 0        1889.7       1890.00      1838.00       1855.75        285.40
# 1        1848.0       1862.75      1828.00       1842.82        284.00
# 2        1864.1       1910.00      1864.10       1893.91        283.00
# 3        1906.0       1909.80      1880.10       1889.21        288.85
# 4        1867.0       1894.85      1808.35       1873.32        285.00
#
#    High-Stock-2  Low-Stock-2  VWAP-Stock-2  Open-Stock-3  High-Stock-3  ...  \
# 0        285.95       281.50        283.72       2095.00        2097.8  ...
# 1        284.80       279.25        281.05       2061.45        2098.0  ...
# 2        286.85       282.50        285.34       2131.50        2131.5  ...
# 3        291.80       277.00        289.81       2114.90        2156.0  ...
# 4        289.10       285.00        287.01       2132.35        2209.0  ...
#
#    VWAP-Stock-4  Open-Stock-5  High-Stock-5  Low-Stock-5  VWAP-Stock-5  \
# ...

# %%
def test(models, data, iterations = 100):
    results = {}
    for i in models:
        r2_train = []
        r2_test = []
        for j in range(iterations):
            X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2)
            r2_test.append(metrics.r2_score(y_test,
                                            models[i].fit(X_train, 
                                                         y_train).predict(X_test)))
            r2_train.append(metrics.r2_score(y_train, 
                                             models[i].fit(X_train, 
                                                          y_train).predict(X_train)))
        results[i] = [mean(r2_train), mean(r2_test)]
    return DataFrame(results)

# %%
test(models2, data)
# Out:
# /home/kamesh/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16752.656840749456, tolerance: 4499.11343142887
#   model = cd_fast.enet_coordinate_descent(
# /home/kamesh/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 163.4496821238164, tolerance: 48.4947259330544
#   model = cd_fast.enet_coordinate_descent(
# /home/kamesh/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25757.336046337998, tolerance: 1398.2155624476993
#   model = cd_fast.enet_coordinate_descent(
# ...
